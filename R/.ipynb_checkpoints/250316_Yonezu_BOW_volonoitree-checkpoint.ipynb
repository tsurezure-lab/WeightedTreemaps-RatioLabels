# %%
# remove.packages("WeightedTreemaps")
# devtools::install_local("/Users/hdymacuser/R_date_analysis/WeightedTreemaps", force = TRUE)

# %%
install.packages("nlme")
install.packages("Matrix")
install.packages("mgcv")
install.packages("ggplot2")
install.packages("tidyverse")
# Out:
# Warning message in install.packages("nlme"):
# “パッケージ ‘nlme’ のインストールは、ゼロでない終了値をもちました”
# '.Library' 中のパッケージの HTML 索引を更新します
#
# Making 'packages.html' ...
#  完了
#
# Warning message in install.packages("Matrix"):
# “パッケージ ‘Matrix’ のインストールは、ゼロでない終了値をもちました”
# '.Library' 中のパッケージの HTML 索引を更新します
#
# Making 'packages.html' ...
#  完了
#
# Warning message in install.packages("mgcv"):
# “パッケージ ‘mgcv’ のインストールは、ゼロでない終了値をもちました”
# '.Library' 中のパッケージの HTML 索引を更新します
#
# Making 'packages.html' ...
#  完了
#
# '.Library' 中のパッケージの HTML 索引を更新します
#
# Making 'packages.html' ...
#  完了
#
# '.Library' 中のパッケージの HTML 索引を更新します
#
# Making 'packages.html' ...
#  完了

# %%
install.packages("png")
# Out:
# '.Library' 中のパッケージの HTML 索引を更新します
#
# Making 'packages.html' ...
#  完了

# %%
# 必要なライブラリ
library(dplyr)
library(sysfonts)
library(showtext)
# Out:
# 次のパッケージを付け加えます: ‘dplyr’
#
#
# 以下のオブジェクトは ‘package:stats’ からマスクされています:
#
#     filter, lag
#
#
# 以下のオブジェクトは ‘package:base’ からマスクされています:
#
#     intersect, setdiff, setequal, union
#
#
# Warning message:
# “パッケージ ‘sysfonts’ はバージョン 4.4.3 の R の下で造られました”
# Warning message:
# “パッケージ ‘showtext’ はバージョン 4.4.3 の R の下で造られました”
# 要求されたパッケージ showtextdb をロード中です
#
# Warning message:
# “パッケージ ‘showtextdb’ はバージョン 4.4.3 の R の下で造られました”

# %%
# 必要なライブラリを読み込む
library(WeightedTreemaps) # 重み付きツリーマップ作成用
library(dplyr)          # データ操作用
library(showtext)       # フォントを扱う用
library(grid)           # グラフィックス描画用
library(ggplot2)        # グラフ作成用
library(png)            # PNG画像の読み込み/書き出し用

# Googleフォントを追加する (Zen Maru Gothicを使用)
font_add_google("Zen Maru Gothic", "zenmaru")
# showtextによるフォントの自動使用を有効にする
showtext_auto()

# CSVファイルのパスを設定する (各自の環境に合わせて変更)
file_path <- "/Users/hdymacuser/R_date_analysis/WeightedTreemaps/data/clustered_texts_2stage (3).csv"
# CSVファイルを読み込み、データフレームdfに格納する
df <- read.csv(file_path)

# データ準備: 一次クラスタと二次クラスタを別々に集計する

# 二次クラスタごとの件数、二次クラスタの平均比率を計算
df_secondary <- df %>%
  group_by(secondary_cluster_name) %>%  # 二次クラスタ名でグループ化
  summarise(
    count = n(),                          # 各グループの件数をカウント
    secondary_cluster_ratio = mean(secondary_cluster_ratio, na.rm = TRUE), # 二次クラスタ比率の平均を計算 (欠損値は除外)
    .groups = 'drop'                      # グループ化を解除
  ) %>% filter(count > 0)                 # 件数が0より大きいもののみ抽出

# 一次クラスタごとの件数、一次クラスタの平均比率を計算
df_primary <- df %>%
  group_by(primary_cluster_name) %>%    # 一次クラスタ名でグループ化
  summarise(
    count = n(),                          # 各グループの件数をカウント
    primary_cluster_ratio = mean(primary_cluster_ratio, na.rm = TRUE), # 一次クラスタ比率の平均を計算 (欠損値は除外)
    .groups = 'drop'                      # グループ化を解除
  ) %>% filter(count > 0)                 # 件数が0より大きいもののみ抽出

# 二次クラスタと一次クラスタの組み合わせごとの件数を計算し、
# 二次クラスタ比率と一次クラスタ比率を追加する
df_counts <- df %>%
  group_by(secondary_cluster_name, primary_cluster_name) %>%  # 二次クラスタ名と一次クラスタ名でグループ化
  summarise(
    count = n(),                          # 各グループの件数をカウント
    .groups = 'drop'                      # グループ化を解除
  ) %>%
  filter(count > 0) %>%                 # 件数が0より大きいもののみ抽出
  left_join(df_secondary %>% select(secondary_cluster_name, secondary_cluster_ratio), by = "secondary_cluster_name") %>% # 二次クラスタ情報を結合
  left_join(df_primary %>% select(primary_cluster_name, primary_cluster_ratio), by = "primary_cluster_name")          # 一次クラスタ情報を結合

# Voronoi Treemap (ボロノイ図) を作成
tm <- voronoiTreemap(
  data = df_counts,                                           # ツリーマップのデータ
  levels = c("secondary_cluster_name", "primary_cluster_name"), # 階層構造を指定 (二次クラスタ -> 一次クラスタ)
  cell_size = "count",                                        # セルの大きさを決める変数 (件数)
  shape = "rounded_rect",                                     # セルの形状 (角丸四角形)
  positioning = "clustered",                                  # セルの配置方法 (クラスタ化)
  error_tol = 0.01,                                           # 許容誤差
  maxIteration = 100,                                         # 最大反復回数
  label_ratios = c("primary_cluster_ratio", "secondary_cluster_ratio"), # ラベルとして表示する比率
  verbose = TRUE                                              # 詳細なログを出力
)

# 出力画像の幅、高さ、解像度を設定
width_px <- 1200
height_px <- 675
dpi <- 300
# 出力ファイル名を指定
output_filename <- "treemap.png"

# ツリーマップを描画するgrob(グラフィカルオブジェクト)を作成
treemap_grob <- grid.grabExpr({
  grid::grid.newpage() # 新しい描画ページを作成

  # ツリーマップ用のビューポートを設定（下に移動）
  # pushViewport(viewport(y = unit(0.02, "npc"), height = unit(0.88, "npc"), just = "bottom"))
　pushViewport(viewport(y = unit(0.0, "npc"), height = unit(0.0, "npc"), just = "bottom"))
  drawTreemap(tm,
    label_level = c(1, 2),                                     # ラベルを表示する階層 (1: 二次クラスタ, 2: 一次クラスタ)
    label_color = c(adjustcolor(grey(1), alpha.f = 0.8), adjustcolor(grey(0.85), alpha.f = 0.80)), # ラベルの色
    label_size = c(0.65, 0.8),                                 # ラベルのサイズ
    label_autoscale = TRUE,                                   # ラベルの自動スケーリングを有効化
    label_fontfamily = "zenmaru",                             # ラベルのフォントファミリー
    label_fontweight = "bold",                                 # ラベルのフォントの太さ
    label_line_spacing = c(1.0, 0.0),                                # ラベルの行間
    label_ratio = c(1, 2),                                     # 比率を表示するかどうか
    label_ratio_color = c(adjustcolor(grey(1), alpha.f = 0.8), adjustcolor(grey(0.85), alpha.f = 0.80)), # ラベルの色
    label_ratio_size = 0.5,                                   # 比率のラベルのサイズ
    label_ratio_fontfamily = "zenmaru",                        # 比率のラベルのフォントファミリー
    label_ratio_fontweight = "bold",                           # 比率のラベルのフォントの太さ
    border_size = 1.0,                                         # 境界線の太さ
    border_color = grey(0.8),                                  # 境界線の色
    border_alpha = 0.6,                                       # 境界線の透明度
    color_type = "categorical",                               # 色のタイプ (カテゴリカル)
    color_level = 1,                                           # 色を適用する階層 (1: 二次クラスタ)
    title = NULL,                                              # タイトルは設定しない,
    y_offset = -0.015  # ツリーマップを下方に移動
  )
  popViewport() # ビューポートを元に戻す

  # タイトルを別途描画（太字に修正）
  grid::grid.text(
    "「米津玄師 Kenshi Yonezu - BOW AND ARROW」コメントクラスター",
    x = unit(0.5, "npc"),
    y = unit(0.98, "npc"),
    gp = gpar(fontsize = 18, fontfamily = "zenmaru", fontface = "bold", col = grey(0.1)) # fontweight を fontface に変更
  )
}, wrap.grobs = TRUE)


# 総レビュー数を計算
total_reviews <- nrow(df)
# キャプション(説明文)のgrobを作成
caption_grob <- textGrob(
  paste0("YouTube動画の", format(total_reviews, big.mark = ","), "件のコメントより徒然研究室が2025年3月10日作成"), # キャプション文字列
  x = unit(0.01, "npc"),  # X座標 (左端)
  y = unit(0.01, "npc"), # Y座標 (下端)
  hjust = 0,             # 水平方向の配置 (左寄せ)
  vjust = 0,             # 垂直方向の配置 (下寄せ)
  gp = gpar(fontsize = 7, fontfamily = "zenmaru", fontface = "bold", col = grey(0.2)) # フォント等の設定
)

# 最終的なプロットを作成 (ggplotを使用)
final_plot <- ggplot() +
  annotation_custom(treemap_grob) +   # ツリーマップのgrobを追加
  annotation_custom(caption_grob) +  # キャプションのgrobを追加
  theme_void() +                     # 空白のテーマを使用 (軸などを非表示)
  theme(plot.background = element_rect(fill = "#F9F4EE", color = NA)) # 背景色を設定

# グラフをPNGファイルとして保存
ggsave(output_filename, final_plot, width = width_px, height = height_px, units = "px", dpi = dpi)
# 保存したPNGファイルを読み込む
img <- readPNG(output_filename)
# 読み込んだPNG画像をラスタ形式で描画
grid::grid.raster(img)

# 処理完了メッセージを表示
cat("### 処理が正常に終了しました ###\n")
# Out:
# Level 1 tesselation: 0.79 % mean error, 1.8 % max error, 100 iterations.
#
# Level 2 tesselation: 0.18 % mean error, 0.93 % max error, 57 iterations.
#
# Level 2 tesselation: 0.22 % mean error, 0.91 % max error, 61 iterations.
#
# Level 2 tesselation: 0.2 % mean error, 0.87 % max error, 59 iterations.
#
# Level 2 tesselation: 0.23 % mean error, 0.98 % max error, 53 iterations.
#
# Level 2 tesselation: 0.28 % mean error, 0.96 % max error, 51 iterations.
#
# Level 2 tesselation: 0.21 % mean error, 0.97 % max error, 60 iterations.
#
# Treemap successfully created.
# Debug: label_ratio_levels = 1 2
# Debug: treemap@label_ratios exists = TRUE
# Debug: label_ratios names = primary_cluster_ratio secondary_cluster_ratio
# Processing cell: LEVEL1_アニメとコラボへの期待 (Raw: アニメとコラボへの期待, Clean: アニメとコラボへの期待), Level: 1
# Level 1 - Name: アニメとコラボへの期待 Matched: アニメとコラボへの期待 Ratio: 21.04
# Processing cell: LEVEL1_羽生結弦の凄さ再認識と称賛 (Raw: 羽生結弦の凄さ再認識と称賛, Clean: 羽生結弦の凄さ再認識と称賛), Level: 1
# Processing cell: LEVEL2_コラボへの喜びと称賛 (Raw: コラボへの喜びと称賛, Clean: コラボへの喜びと称賛), Level: 2
# Level 2 - Name: コラボへの喜びと称賛 Matched: コラボへの喜びと称賛 Ratio: 1.93
# Processing cell: LEVEL2_フィギュアへの深い感動 (Raw: フィギュアへの深い感動, Clean: フィギュアへの深い感動), Level: 2
# Level 2 - Name: フィギュアへの深い感動 Matched: フィギュアへの深い感動 Ratio: 1.35
# Processing cell: LEVEL2_メイキングへの期待 (Raw: メイキングへの期待, Clean: メイキングへの期待), Level: 2
# Level 2 - Name: メイキングへの期待 Matched: メイキングへの期待 Ratio: 0.91
# Processing cell: LEVEL2_メダリストへの言及 (Raw: メダリストへの言及, Clean: メダリストへの言及), Level: 2
# Level 2 - Name: メダリストへの言及 Matched: メダリストへの言及 Ratio: 1.392411
# Processing cell: LEVEL2_リアルタイムな視聴状況 (Raw: リアルタイムな視聴状況, Clean: リアルタイムな視聴状況), Level: 2
# Level 2 - Name: リアルタイムな視聴状況 Matched: リアルタイムな視聴状況 Ratio: 0.52
# Processing cell: LEVEL2_愛と感謝の表現 (Raw: 愛と感謝の表現, Clean: 愛と感謝の表現), Level: 2
# Level 2 - Name: 愛と感謝の表現 Matched: 愛と感謝の表現 Ratio: 0.38
# Processing cell: LEVEL2_愛と喜びの表現 (Raw: 愛と喜びの表現, Clean: 愛と喜びの表現), Level: 2
# Level 2 - Name: 愛と喜びの表現 Matched: 愛と喜びの表現 Ratio: 0.39
# Processing cell: LEVEL2_印象的なシーンへの言及 (Raw: 印象的なシーンへの言及, Clean: 印象的なシーンへの言及), Level: 2
# Level 2 - Name: 印象的なシーンへの言及 Matched: 印象的なシーンへの言及 Ratio: 0.32
# Processing cell: LEVEL2_羽生結弦の圧巻の演技 (Raw: 羽生結弦の圧巻の演技, Clean: 羽生結弦の圧巻の演技), Level: 2
# Level 2 - Name: 羽生結弦の圧巻の演技 Matched: 羽生結弦の圧巻の演技 Ratio: 1.22
# Processing cell: LEVEL2_羽生結弦の技術への言及 (Raw: 羽生結弦の技術への言及, Clean: 羽生結弦の技術への言及), Level: 2
# Level 2 - Name: 羽生結弦の技術への言及 Matched: 羽生結弦の技術への言及 Ratio: 0.55
# Processing cell: LEVEL2_羽生結弦の凄さへの再認識 (Raw: 羽生結弦の凄さへの再認識, Clean: 羽生結弦の凄さへの再認識), Level: 2
# Level 2 - Name: 羽生結弦の凄さへの再認識 Matched: 羽生結弦の凄さへの再認識 Ratio: 1.72
# Processing cell: LEVEL2_羽生結弦の凄さ再認識 (Raw: 羽生結弦の凄さ再認識, Clean: 羽生結弦の凄さ再認識), Level: 2
# Level 2 - Name: 羽生結弦の凄さ再認識 Matched: 羽生結弦の凄さ再認識 Ratio: 0.79
# Processing cell: LEVEL2_羽生結弦への応援と期待 (Raw: 羽生結弦への応援と期待, Clean: 羽生結弦への応援と期待), Level: 2
# Level 2 - Name: 羽生結弦への応援と期待 Matched: 羽生結弦への応援と期待 Ratio: 2.37
# Level 2 - Name: 感情を揺さぶるシンプルさ Matched: 感情を揺さぶるシンプルさ Ratio: 2.29
# Processing cell: LEVEL2_感情を揺さぶる作品 (Raw: 感情を揺さぶる作品, Clean: 感情を揺さぶる作品), Level: 2
# Level 2 - Name: 感情を揺さぶる作品 Matched: 感情を揺さぶる作品 Ratio: 1.128025
# Processing cell: LEVEL2_感情を揺さぶる作品 (Raw: 感情を揺さぶる作品, Clean: 感情を揺さぶる作品), Level: 2
# Level 2 - Name: 感情を揺さぶる作品 Matched: 感情を揺さぶる作品 Ratio: 1.128025
# Processing cell: LEVEL2_感情を揺さぶる表現力 (Raw: 感情を揺さぶる表現力, Clean: 感情を揺さぶる表現力), Level: 2
# Level 2 - Name: 感情を揺さぶる表現力 Matched: 感情を揺さぶる表現力 Ratio: 1.15
# Processing cell: LEVEL2_感動と共感の嵐 (Raw: 感動と共感の嵐, Clean: 感動と共感の嵐), Level: 2
# Level 2 - Name: 感動と共感の嵐 Matched: 感動と共感の嵐 Ratio: 0.8
# Processing cell: LEVEL2_感動と興奮を呼ぶ作品 (Raw: 感動と興奮を呼ぶ作品, Clean: 感動と興奮を呼ぶ作品), Level: 2
# Level 2 - Name: 感動と興奮を呼ぶ作品 Matched: 感動と興奮を呼ぶ作品 Ratio: 1.68
# Processing cell: LEVEL2_感動と称賛の嵐 (Raw: 感動と称賛の嵐, Clean: 感動と称賛の嵐), Level: 2
# Level 2 - Name: 感動と称賛の嵐 Matched: 感動と称賛の嵐 Ratio: 1.074167
# Processing cell: LEVEL2_感動と称賛の嵐 (Raw: 感動と称賛の嵐, Clean: 感動と称賛の嵐), Level: 2
# Level 2 - Name: 感動と称賛の嵐 Matched: 感動と称賛の嵐 Ratio: 1.074167
# Processing cell: LEVEL2_簡潔な称賛の言葉 (Raw: 簡潔な称賛の言葉, Clean: 簡潔な称賛の言葉), Level: 2
# Level 2 - Name: 簡潔な称賛の言葉 Matched: 簡潔な称賛の言葉 Ratio: 0.65
# Processing cell: LEVEL2_関係性への考察 (Raw: 関係性への考察, Clean: 関係性への考察), Level: 2
# Level 2 - Name: 関係性への考察 Matched: 関係性への考察 Ratio: 1.94
# Processing cell: LEVEL2_記録更新への祝福 (Raw: 記録更新への祝福, Clean: 記録更新への祝福), Level: 2
# Level 2 - Name: 記録更新への祝福 Matched: 記録更新への祝福 Ratio: 0.38
# Processing cell: LEVEL2_金銭的なやり取り (Raw: 金銭的なやり取り, Clean: 金銭的なやり取り), Level: 2
# Level 2 - Name: 金銭的なやり取り Matched: 金銭的なやり取り Ratio: 0.57
# Processing cell: LEVEL2_好意的な反応と称賛 (Raw: 好意的な反応と称賛, Clean: 好意的な反応と称賛), Level: 2
# Level 2 - Name: 好意的な反応と称賛 Matched: 好意的な反応と称賛 Ratio: 1.08
# Processing cell: LEVEL2_豪華さへの圧倒と考察 (Raw: 豪華さへの圧倒と考察, Clean: 豪華さへの圧倒と考察), Level: 2
# Level 2 - Name: 豪華さへの圧倒と考察 Matched: 豪華さへの圧倒と考察 Ratio: 1.08
# Level 2 - Name: 美しさへの感動 Matched: 美しさへの感動 Ratio: 1.22
# Processing cell: LEVEL2_美しさへの称賛 (Raw: 美しさへの称賛, Clean: 美しさへの称賛), Level: 2
# Level 2 - Name: 美しさへの称賛 Matched: 美しさへの称賛 Ratio: 0.58
# Processing cell: LEVEL2_米津と羽生の輝きに魅了 (Raw: 米津と羽生の輝きに魅了, Clean: 米津と羽生の輝きに魅了), Level: 2
# Level 2 - Name: 米津と羽生の輝きに魅了 Matched: 米津と羽生の輝きに魅了 Ratio: 1.73
# Processing cell: LEVEL2_米津玄師への称賛 (Raw: 米津玄師への称賛, Clean: 米津玄師への称賛), Level: 2
# Level 2 - Name: 米津玄師への称賛 Matched: 米津玄師への称賛 Ratio: 1.92
# Processing cell: LEVEL2_米津玄師への誕生日祝い (Raw: 米津玄師への誕生日祝い, Clean: 米津玄師への誕生日祝い), Level: 2
# Level 2 - Name: 米津玄師への誕生日祝い Matched: 米津玄師への誕生日祝い Ratio: 0.16
# Processing cell: LEVEL2_魅了されるコラボ (Raw: 魅了されるコラボ, Clean: 魅了されるコラボ), Level: 2
# Level 2 - Name: 魅了されるコラボ Matched: 魅了されるコラボ Ratio: 1.4
# Processing cell: LEVEL2_無料視聴への驚き (Raw: 無料視聴への驚き, Clean: 無料視聴への驚き), Level: 2
# Level 2 - Name: 無料視聴への驚き Matched: 無料視聴への驚き Ratio: 0.51
# Processing cell: LEVEL2_踊ってみたへの期待 (Raw: 踊ってみたへの期待, Clean: 踊ってみたへの期待), Level: 2
# Level 2 - Name: 踊ってみたへの期待 Matched: 踊ってみたへの期待 Ratio: 0.44
# Processing cell: LEVEL2_涙を誘う美しさ (Raw: 涙を誘う美しさ, Clean: 涙を誘う美しさ), Level: 2
# Level 2 - Name: 涙を誘う美しさ Matched: 涙を誘う美しさ Ratio: 0.32
# [1] "Ratio labels prepared:"
# $LEVEL1_アニメとコラボへの期待
# [1] "21.0%"
#
# $LEVEL1_羽生結弦の凄さ再認識と称賛
# [1] "21.3%"
#
# $LEVEL1_感謝と誇りを呼び起こす瞬間
# [1] "11.0%"
#
# $LEVEL1_感情を揺さぶるシンプルさ
# [1] "15.9%"
#
# $LEVEL1_世界を魅了するコラボへの感動
# [1] "16.7%"
#
# $LEVEL1_天才2人の疾走感とこだわり
# [1] "14.1%"
#
# $LEVEL2_2人の才能への賛辞
# [1] "1.5%"
#
# $LEVEL2_2人の天才が魅せる疾走感
# [1] "0.7%"
#
# $LEVEL2_GOATへの賛辞
# [1] "0.1%"
#
# $LEVEL2_Yuzuruへの揺るぎない愛
# [1] "0.4%"
#
# $LEVEL2_アニメへの期待と共感
# [1] "0.5%"
#
# $LEVEL2_コメント欄の反応
# [1] "1.5%"
#
# $LEVEL2_コラボへの感動と称賛
# [1] "1.5%"
#
# $LEVEL2_コラボへの喜びと祝福
# [1] "0.1%"
#
# $LEVEL2_コラボへの喜びと称賛
# [1] "1.9%"
#
# $LEVEL2_フィギュアへの深い感動
# [1] "1.4%"
#
# $LEVEL2_メイキングへの期待
# [1] "0.9%"
#
# $LEVEL2_メダリストへの言及
# [1] "1.4%"
#
# $LEVEL2_リアルタイムな視聴状況
# [1] "0.5%"
#
# $LEVEL2_愛と感謝の表現
# [1] "0.4%"
#
# $LEVEL2_愛と喜びの表現
# [1] "0.4%"
#
# $LEVEL2_印象的なシーンへの言及
# [1] "0.3%"
#
# $LEVEL2_羽生結弦の圧巻の演技
# [1] "1.2%"
#
# $LEVEL2_羽生結弦の技術への言及
# [1] "0.6%"
#
# $LEVEL2_羽生結弦の凄さへの再認識
# [1] "1.7%"
#
# $LEVEL2_羽生結弦の凄さ再認識
# [1] "0.8%"
#
# $LEVEL2_羽生結弦への応援と期待
# [1] "2.4%"
#
# $LEVEL2_羽生結弦への賛辞と感謝
# [1] "1.3%"
#
# $LEVEL2_羽生結弦への称賛
# [1] "3.1%"
#
# $LEVEL2_羽生結弦への新たな興味
# [1] "0.7%"
#
# $LEVEL2_羽生結弦への新たな発見
# [1] "1.8%"
#
# $LEVEL2_映画のような作品
# [1] "0.1%"
#
# $LEVEL2_映像への驚きと興奮
# [1] "1.3%"
#
# $LEVEL2_映像への深い没入感
# [1] "1.4%"
#
# $LEVEL2_映像制作への考察
# [1] "0.5%"
#
# $LEVEL2_映像美と表現への称賛
# [1] "1.1%"
#
# $LEVEL2_映像美への考察
# [1] "0.6%"
#
# $LEVEL2_映像美への称賛
# [1] "0.8%"
#
# $LEVEL2_応援と肯定的な反応
# [1] "0.6%"
#
# $LEVEL2_歌詞の内容と考察
# [1] "0.7%"
#
# $LEVEL2_楽曲とMVへの深い考察
# [1] "1.6%"
#
# $LEVEL2_楽曲と羽生の融合
# [1] "1.0%"
#
# $LEVEL2_楽曲と映像への共感
# [1] "1.1%"
#
# $LEVEL2_楽曲と演技への感動
# [1] "1.6%"
#
# $LEVEL2_楽曲と表現の相乗効果
# [1] "1.1%"
#
# $LEVEL2_楽曲と表現への称賛
# [1] "2.2%"
#
# $LEVEL2_楽曲への共感と称賛
# [1] "0.4%"
#
# $LEVEL2_楽曲への挑戦と共感
# [1] "1.3%"
#
# $LEVEL2_完璧なコラボへの賛辞
# [1] "0.9%"
#
# $LEVEL2_完璧な二人の芸術作品
# [1] "0.9%"
#
# $LEVEL2_感謝と感動を呼び起こす瞬間
# [1] "0.9%"
#
# $LEVEL2_感謝と祝福の言葉
# [1] "0.9%"
#
# $LEVEL2_感情を揺さぶるシンプルさ
# [1] "2.3%"
#
# $LEVEL2_感情を揺さぶる作品
# [1] "1.1%"
#
# $LEVEL2_感情を揺さぶる表現力
# [1] "1.1%"
#
# $LEVEL2_感動と共感の嵐
# [1] "0.8%"
#
# $LEVEL2_感動と興奮を呼ぶ作品
# [1] "1.7%"
#
# $LEVEL2_感動と称賛の嵐
# [1] "1.1%"
#
# $LEVEL2_簡潔な称賛の言葉
# [1] "0.7%"
#
# $LEVEL2_関係性への考察
# [1] "1.9%"
#
# $LEVEL2_記録更新への祝福
# [1] "0.4%"
#
# $LEVEL2_金銭的なやり取り
# [1] "0.6%"
#
# $LEVEL2_好意的な反応と称賛
# [1] "1.1%"
#
# $LEVEL2_豪華さへの圧倒と考察
# [1] "1.1%"
#
# $LEVEL2_再生回数の驚異的な伸び
# [1] "0.6%"
#
# $LEVEL2_再生回数増加への祝福
# [1] "0.6%"
#
# $LEVEL2_最高のコラボへの称賛
# [1] "0.2%"
#
# $LEVEL2_作品への期待と興奮
# [1] "0.5%"
#
# $LEVEL2_作品への称賛と感動
# [1] "1.2%"
#
# $LEVEL2_作品への深い感動
# [1] "1.1%"
#
# $LEVEL2_作品への深い考察と評価
# [1] "0.6%"
#
# $LEVEL2_作品への熱狂的な愛
# [1] "0.5%"
#
# $LEVEL2_作品への様々な反応
# [1] "2.0%"
#
# $LEVEL2_心を奪われる作品
# [1] "0.8%"
#
# $LEVEL2_神レベルのコラボ
# [1] "0.7%"
#
# $LEVEL2_推しコラボへの興奮
# [1] "1.2%"
#
# $LEVEL2_推しへの感謝と祝福
# [1] "1.5%"
#
# $LEVEL2_推し活の喜びと誇り
# [1] "1.0%"
#
# $LEVEL2_世界からの称賛
# [1] "0.7%"
#
# $LEVEL2_世界を魅了するコラボ
# [1] "1.0%"
#
# $LEVEL2_世界的な反響と感動
# [1] "1.0%"
#
# $LEVEL2_誕生日祝いと祝福
# [1] "0.7%"
#
# $LEVEL2_誕生日祝いと熱狂的な称賛
# [1] "1.0%"
#
# $LEVEL2_天才たちの芸術
# [1] "0.7%"
#
# $LEVEL2_天才への称賛と感動
# [1] "0.8%"
#
# $LEVEL2_日本の誇りへの賛辞
# [1] "0.7%"
#
# $LEVEL2_美しさと楽曲への共感
# [1] "2.2%"
#
# $LEVEL2_美しさへの感動
# [1] "1.2%"
#
# $LEVEL2_美しさへの称賛
# [1] "0.6%"
#
# $LEVEL2_米津と羽生の輝きに魅了
# [1] "1.7%"
#
# $LEVEL2_米津玄師への称賛
# [1] "1.9%"
#
# $LEVEL2_米津玄師への誕生日祝い
# [1] "0.2%"
#
# $LEVEL2_魅了されるコラボ
# [1] "1.4%"
#
# $LEVEL2_無料視聴への驚き
# [1] "0.5%"
#
# $LEVEL2_踊ってみたへの期待
# [1] "0.4%"
#
# $LEVEL2_涙を誘う美しさ
# [1] "0.3%"
#
# Drawing label for: アニメとコラボへの期待 at x: 1572.192 y: 485.1208
# Debug: cell_id = LEVEL1_アニメとコラボへの期待 for tm_slot$name = アニメとコラボへの期待
# Drawing ratio label for: アニメとコラボへの期待 Value: 21.0% at x: 1572.192 y: 384.2187
# Drawing label for: 羽生結弦の凄さ再認識と称賛 at x: 1077.024 y: 1115.355
# Debug: cell_id = LEVEL1_羽生結弦の凄さ再認識と称賛 for tm_slot$name = 羽生結弦の凄さ再認識と称賛
# Drawing ratio label for: 羽生結弦の凄さ再認識と称賛 Value: 21.3% at x: 1077.024 y: 1014.979
# Drawing label for: 感謝と誇りを呼び起こす瞬間 at x: 279.3338 y: 1050.461
# Debug: cell_id = LEVEL1_感謝と誇りを呼び起こす瞬間 for tm_slot$name = 感謝と誇りを呼び起こす瞬間
# Drawing ratio label for: 感謝と誇りを呼び起こす瞬間 Value: 11.0% at x: 279.3338 y: 963.1054
# Drawing label for: 感情を揺さぶるシンプルさ at x: 1611.895 y: 1610.535
# Debug: cell_id = LEVEL1_感情を揺さぶるシンプルさ for tm_slot$name = 感情を揺さぶるシンプルさ
# Drawing ratio label for: 感情を揺さぶるシンプルさ Value: 15.9% at x: 1611.895 y: 1514.475
# Drawing label for: 世界を魅了するコラボへの感動 at x: 542.3331 y: 359.5716
# Debug: cell_id = LEVEL1_世界を魅了するコラボへの感動 for tm_slot$name = 世界を魅了するコラボへの感動
# Drawing ratio label for: 世界を魅了するコラボへの感動 Value: 16.7% at x: 542.3331 y: 261.9093
# Drawing label for: 天才2人の疾走感とこだわり at x: 532.7935 y: 1726.394
# Debug: cell_id = LEVEL1_天才2人の疾走感とこだわり for tm_slot$name = 天才2人の疾走感とこだわり
# Drawing ratio label for: 天才2人の疾走感とこだわり Value: 14.1% at x: 532.7935 y: 1633.258
# Drawing label for: 2人の才能への賛辞 at x: 920.5701 y: 146.8605
# Debug: cell_id = LEVEL2_2人の才能への賛辞 for tm_slot$name = 2人の才能への賛辞
# Drawing ratio label for: 2人の才能への賛辞 Value: 1.5% at x: 920.5701 y: 98.49979
# Drawing label for: 2人の天才が魅せる疾走感 at x: 1018.861 y: 1920.676
# Debug: cell_id = LEVEL2_2人の天才が魅せる疾走感 for tm_slot$name = 2人の天才が魅せる疾走感
# Drawing ratio label for: 2人の天才が魅せる疾走感 Value: 0.7% at x: 1018.861 y: 1875.725
# Drawing label for: GOATへの賛辞 at x: 320.4219 y: 1442.618
# Debug: cell_id = LEVEL2_GOATへの賛辞 for tm_slot$name = GOATへの賛辞
# Drawing ratio label for: GOATへの賛辞 Value: 0.1% at x: 320.4219 y: 1400.439
# Drawing label for: Yuzuruへの揺るぎない愛 at x: 851.7485 y: 700.385
# Debug: cell_id = LEVEL2_Yuzuruへの揺るぎない愛 for tm_slot$name = Yuzuruへの揺るぎない愛
# Drawing ratio label for: Yuzuruへの揺るぎない愛 Value: 0.4% at x: 851.7485 y: 656.9635
# Drawing label for: アニメへの期待と共感 at x: 61.31366 y: 1732
# Debug: cell_id = LEVEL2_アニメへの期待と共感 for tm_slot$name = アニメへの期待と共感
# Drawing ratio label for: アニメへの期待と共感 Value: 0.5% at x: 61.31366 y: 1688.062
# Drawing label for: コメント欄の反応 at x: 717.1276 y: 1245.027
# Debug: cell_id = LEVEL2_コメント欄の反応 for tm_slot$name = コメント欄の反応
# Drawing ratio label for: コメント欄の反応 Value: 1.5% at x: 717.1276 y: 1198.327
# Drawing label for: コラボへの感動と称賛 at x: 325.5808 y: 549.8541
# Debug: cell_id = LEVEL2_コラボへの感動と称賛 for tm_slot$name = コラボへの感動と称賛
# Drawing ratio label for: コラボへの感動と称賛 Value: 1.5% at x: 325.5808 y: 502.7251
# Drawing label for: コラボへの喜びと祝福 at x: 25.85662 y: 597.2408
# Debug: cell_id = LEVEL2_コラボへの喜びと祝福 for tm_slot$name = コラボへの喜びと祝福
# Drawing ratio label for: コラボへの喜びと祝福 Value: 0.1% at x: 25.85662 y: 555.5388
# Drawing label for: コラボへの喜びと称賛 at x: 1873.008 y: 922.6741
# Debug: cell_id = LEVEL2_コラボへの喜びと称賛 for tm_slot$name = コラボへの喜びと称賛
# Drawing ratio label for: コラボへの喜びと称賛 Value: 1.9% at x: 1873.008 y: 874.975
# Drawing label for: フィギュアへの深い感動 at x: 499.5705 y: 1443.155
# Debug: cell_id = LEVEL2_フィギュアへの深い感動 for tm_slot$name = フィギュアへの深い感動
# Drawing ratio label for: フィギュアへの深い感動 Value: 1.4% at x: 499.5705 y: 1396.409
# Drawing label for: メイキングへの期待 at x: 107.4089 y: 1402.422
# Debug: cell_id = LEVEL2_メイキングへの期待 for tm_slot$name = メイキングへの期待
# Drawing ratio label for: メイキングへの期待 Value: 0.9% at x: 107.4089 y: 1356.881
# Drawing label for: メダリストへの言及 at x: 1259.559 y: 145.567
# Debug: cell_id = LEVEL2_メダリストへの言及 for tm_slot$name = メダリストへの言及
# Drawing ratio label for: メダリストへの言及 Value: 1.4% at x: 1259.559 y: 96.54628
# Drawing label for: リアルタイムな視聴状況 at x: 104.3756 y: 201.3797
# Debug: cell_id = LEVEL2_リアルタイムな視聴状況 for tm_slot$name = リアルタイムな視聴状況
# Drawing ratio label for: リアルタイムな視聴状況 Value: 0.5% at x: 104.3756 y: 156.6517
# Drawing label for: 愛と感謝の表現 at x: 581.356 y: 1097.74
# Debug: cell_id = LEVEL2_愛と感謝の表現 for tm_slot$name = 愛と感謝の表現
# Drawing ratio label for: 愛と感謝の表現 Value: 0.4% at x: 581.356 y: 1054.216
# Drawing label for: 愛と喜びの表現 at x: 1075.57 y: 1669.777
# Debug: cell_id = LEVEL2_愛と喜びの表現 for tm_slot$name = 愛と喜びの表現
# Drawing ratio label for: 愛と喜びの表現 Value: 0.4% at x: 1075.57 y: 1626.645
# Drawing label for: 印象的なシーンへの言及 at x: 1148.957 y: 1925.837
# Debug: cell_id = LEVEL2_印象的なシーンへの言及 for tm_slot$name = 印象的なシーンへの言及
# Drawing ratio label for: 印象的なシーンへの言及 Value: 0.3% at x: 1148.957 y: 1882.398
# Drawing label for: 羽生結弦の圧巻の演技 at x: 1509.753 y: 1720.811
# Debug: cell_id = LEVEL2_羽生結弦の圧巻の演技 for tm_slot$name = 羽生結弦の圧巻の演技
# Drawing ratio label for: 羽生結弦の圧巻の演技 Value: 1.2% at x: 1509.753 y: 1674.428
# Drawing label for: 羽生結弦の技術への言及 at x: 324.7255 y: 958.6142
# Debug: cell_id = LEVEL2_羽生結弦の技術への言及 for tm_slot$name = 羽生結弦の技術への言及
# Drawing ratio label for: 羽生結弦の技術への言及 Value: 0.6% at x: 324.7255 y: 914.1759
# Drawing label for: 羽生結弦の凄さへの再認識 at x: 1476.666 y: 346.514
# Debug: cell_id = LEVEL2_羽生結弦の凄さへの再認識 for tm_slot$name = 羽生結弦の凄さへの再認識
# Drawing ratio label for: 羽生結弦の凄さへの再認識 Value: 1.7% at x: 1476.666 y: 299.1505
# Drawing label for: 羽生結弦の凄さ再認識 at x: 369.482 y: 1625.641
# Debug: cell_id = LEVEL2_羽生結弦の凄さ再認識 for tm_slot$name = 羽生結弦の凄さ再認識
# Drawing ratio label for: 羽生結弦の凄さ再認識 Value: 0.8% at x: 369.482 y: 1580.385
# Drawing label for: 羽生結弦への応援と期待 at x: 1671.677 y: 1452.389
# Debug: cell_id = LEVEL2_羽生結弦への応援と期待 for tm_slot$name = 羽生結弦への応援と期待
# Drawing ratio label for: 羽生結弦への応援と期待 Value: 2.4% at x: 1671.677 y: 1403.806
# Drawing label for: 羽生結弦への賛辞と感謝 at x: 1752.199 y: 1696.849
# Debug: cell_id = LEVEL2_羽生結弦への賛辞と感謝 for tm_slot$name = 羽生結弦への賛辞と感謝
# Drawing ratio label for: 羽生結弦への賛辞と感謝 Value: 1.3% at x: 1752.199 y: 1650.239
# Drawing label for: 羽生結弦への称賛 at x: 925.9271 y: 1088.288
# Debug: cell_id = LEVEL2_羽生結弦への称賛 for tm_slot$name = 羽生結弦への称賛
# Drawing ratio label for: 羽生結弦への称賛 Value: 3.1% at x: 925.9271 y: 1039.039
# Drawing label for: 羽生結弦への新たな興味 at x: 538.0009 y: 437.2471
# Debug: cell_id = LEVEL2_羽生結弦への新たな興味 for tm_slot$name = 羽生結弦への新たな興味
# Drawing ratio label for: 羽生結弦への新たな興味 Value: 0.7% at x: 538.0009 y: 392.4252
# Drawing label for: 羽生結弦への新たな発見 at x: 1074.935 y: 1522.032
# Debug: cell_id = LEVEL2_羽生結弦への新たな発見 for tm_slot$name = 羽生結弦への新たな発見
# Drawing ratio label for: 羽生結弦への新たな発見 Value: 1.8% at x: 1074.935 y: 1474.804
# Drawing label for: 映画のような作品 at x: 1315.012 y: 1251.361
# Debug: cell_id = LEVEL2_映画のような作品 for tm_slot$name = 映画のような作品
# Drawing ratio label for: 映画のような作品 Value: 0.1% at x: 1315.012 y: 1209.883
# Drawing label for: 映像への驚きと興奮 at x: 1868.442 y: 218.4473
# Debug: cell_id = LEVEL2_映像への驚きと興奮 for tm_slot$name = 映像への驚きと興奮
# Drawing ratio label for: 映像への驚きと興奮 Value: 1.3% at x: 1868.442 y: 171.9959
# Drawing label for: 映像への深い没入感 at x: 1345.769 y: 899.8828
# Debug: cell_id = LEVEL2_映像への深い没入感 for tm_slot$name = 映像への深い没入感
# Drawing ratio label for: 映像への深い没入感 Value: 1.4% at x: 1345.769 y: 853.3198
# Drawing label for: 映像制作への考察 at x: 63.40937 y: 1115.955
# Debug: cell_id = LEVEL2_映像制作への考察 for tm_slot$name = 映像制作への考察
# Drawing ratio label for: 映像制作への考察 Value: 0.5% at x: 63.40937 y: 1071.847
# Drawing label for: 映像美と表現への称賛 at x: 1554.038 y: 105.9876
# Debug: cell_id = LEVEL2_映像美と表現への称賛 for tm_slot$name = 映像美と表現への称賛
# Drawing ratio label for: 映像美と表現への称賛 Value: 1.1% at x: 1554.038 y: 59.94815
# Drawing label for: 映像美への考察 at x: 698.9029 y: 1464.26
# Debug: cell_id = LEVEL2_映像美への考察 for tm_slot$name = 映像美への考察
# Drawing ratio label for: 映像美への考察 Value: 0.6% at x: 698.9029 y: 1419.661
# Drawing label for: 映像美への称賛 at x: 959.0869 y: 817.3781
# Debug: cell_id = LEVEL2_映像美への称賛 for tm_slot$name = 映像美への称賛
# Drawing ratio label for: 映像美への称賛 Value: 0.8% at x: 959.0869 y: 771.2194
# Drawing label for: 応援と肯定的な反応 at x: 489.7089 y: 644.0271
# Debug: cell_id = LEVEL2_応援と肯定的な反応 for tm_slot$name = 応援と肯定的な反応
# Drawing ratio label for: 応援と肯定的な反応 Value: 0.6% at x: 489.7089 y: 599.4585
# Drawing label for: 歌詞の内容と考察 at x: 1747.177 y: 712.417
# Debug: cell_id = LEVEL2_歌詞の内容と考察 for tm_slot$name = 歌詞の内容と考察
# Drawing ratio label for: 歌詞の内容と考察 Value: 0.7% at x: 1747.177 y: 667.6483
# Drawing label for: 楽曲とMVへの深い考察 at x: 344.8899 y: 307.5122
# Debug: cell_id = LEVEL2_楽曲とMVへの深い考察 for tm_slot$name = 楽曲とMVへの深い考察
# Drawing ratio label for: 楽曲とMVへの深い考察 Value: 1.6% at x: 344.8899 y: 260.394
# Drawing label for: 楽曲と羽生の融合 at x: 226.637 y: 1163.335
# Debug: cell_id = LEVEL2_楽曲と羽生の融合 for tm_slot$name = 楽曲と羽生の融合
# Drawing ratio label for: 楽曲と羽生の融合 Value: 1.0% at x: 226.637 y: 1117.553
# Drawing label for: 楽曲と映像への共感 at x: 1642.927 y: 1913.926
# Debug: cell_id = LEVEL2_楽曲と映像への共感 for tm_slot$name = 楽曲と映像への共感
# Drawing ratio label for: 楽曲と映像への共感 Value: 1.1% at x: 1642.927 y: 1867.654
# Drawing label for: 楽曲と演技への感動 at x: 108.2431 y: 434.0838
# Debug: cell_id = LEVEL2_楽曲と演技への感動 for tm_slot$name = 楽曲と演技への感動
# Drawing ratio label for: 楽曲と演技への感動 Value: 1.6% at x: 108.2431 y: 386.805
# Drawing label for: 楽曲と表現の相乗効果 at x: 432.9099 y: 1108.75
# Debug: cell_id = LEVEL2_楽曲と表現の相乗効果 for tm_slot$name = 楽曲と表現の相乗効果
# Drawing ratio label for: 楽曲と表現の相乗効果 Value: 1.1% at x: 432.9099 y: 1062.512
# Drawing label for: 楽曲と表現への称賛 at x: 1861.129 y: 485.3081
# Debug: cell_id = LEVEL2_楽曲と表現への称賛 for tm_slot$name = 楽曲と表現への称賛
# Drawing ratio label for: 楽曲と表現への称賛 Value: 2.2% at x: 1861.129 y: 437.0122
# Drawing label for: 楽曲への共感と称賛 at x: 677.3248 y: 1015.229
# Debug: cell_id = LEVEL2_楽曲への共感と称賛 for tm_slot$name = 楽曲への共感と称賛
# Drawing ratio label for: 楽曲への共感と称賛 Value: 0.4% at x: 677.3248 y: 971.7268
# Drawing label for: 楽曲への挑戦と共感 at x: 1155.62 y: 754.7631
# Debug: cell_id = LEVEL2_楽曲への挑戦と共感 for tm_slot$name = 楽曲への挑戦と共感
# Drawing ratio label for: 楽曲への挑戦と共感 Value: 1.3% at x: 1155.62 y: 708.4481
# Drawing label for: 完璧なコラボへの賛辞 at x: 958.8576 y: 1727.406
# Debug: cell_id = LEVEL2_完璧なコラボへの賛辞 for tm_slot$name = 完璧なコラボへの賛辞
# Drawing ratio label for: 完璧なコラボへの賛辞 Value: 0.9% at x: 958.8576 y: 1681.855
# Drawing label for: 完璧な二人の芸術作品 at x: 1864.514 y: 1854.262
# Debug: cell_id = LEVEL2_完璧な二人の芸術作品 for tm_slot$name = 完璧な二人の芸術作品
# Drawing ratio label for: 完璧な二人の芸術作品 Value: 0.9% at x: 1864.514 y: 1808.888
# Drawing label for: 感謝と感動を呼び起こす瞬間 at x: 363.645 y: 789.9683
# Debug: cell_id = LEVEL2_感謝と感動を呼び起こす瞬間 for tm_slot$name = 感謝と感動を呼び起こす瞬間
# Drawing ratio label for: 感謝と感動を呼び起こす瞬間 Value: 0.9% at x: 363.645 y: 744.3415
# Drawing label for: 感謝と祝福の言葉 at x: 333.3448 y: 1316.478
# Debug: cell_id = LEVEL2_感謝と祝福の言葉 for tm_slot$name = 感謝と祝福の言葉
# Drawing ratio label for: 感謝と祝福の言葉 Value: 0.9% at x: 333.3448 y: 1270.847
# Drawing label for: 感情を揺さぶるシンプルさ at x: 238.8084 y: 1837.867
# Debug: cell_id = LEVEL2_感情を揺さぶるシンプルさ for tm_slot$name = 感情を揺さぶるシンプルさ
# Drawing ratio label for: 感情を揺さぶるシンプルさ Value: 2.3% at x: 238.8084 y: 1789.241
# Drawing label for: 感情を揺さぶる作品 at x: 928.1553 y: 408.6732
# Debug: cell_id = LEVEL2_感情を揺さぶる作品 for tm_slot$name = 感情を揺さぶる作品
# Drawing ratio label for: 感情を揺さぶる作品 Value: 1.1% at x: 928.1553 y: 361.8806
# Drawing label for: 感情を揺さぶる作品 at x: 1583.446 y: 1254.895
# Debug: cell_id = LEVEL2_感情を揺さぶる作品 for tm_slot$name = 感情を揺さぶる作品
# Drawing ratio label for: 感情を揺さぶる作品 Value: 1.1% at x: 1583.446 y: 1210.397
# Drawing label for: 感情を揺さぶる表現力 at x: 489.2758 y: 1902.369
# Debug: cell_id = LEVEL2_感情を揺さぶる表現力 for tm_slot$name = 感情を揺さぶる表現力
# Drawing ratio label for: 感情を揺さぶる表現力 Value: 1.1% at x: 489.2758 y: 1856.119
# Drawing label for: 感動と共感の嵐 at x: 1287.107 y: 1388.848
# Debug: cell_id = LEVEL2_感動と共感の嵐 for tm_slot$name = 感動と共感の嵐
# Drawing ratio label for: 感動と共感の嵐 Value: 0.8% at x: 1287.107 y: 1343.894
# Drawing label for: 感動と興奮を呼ぶ作品 at x: 1352.555 y: 1894.721
# Debug: cell_id = LEVEL2_感動と興奮を呼ぶ作品 for tm_slot$name = 感動と興奮を呼ぶ作品
# Drawing ratio label for: 感動と興奮を呼ぶ作品 Value: 1.7% at x: 1352.555 y: 1847.229
# Drawing label for: 感動と称賛の嵐 at x: 1918.616 y: 1457.016
# Debug: cell_id = LEVEL2_感動と称賛の嵐 for tm_slot$name = 感動と称賛の嵐
# Drawing ratio label for: 感動と称賛の嵐 Value: 1.1% at x: 1918.616 y: 1411.385
# Drawing label for: 感動と称賛の嵐 at x: 127.1381 y: 946.0662
# Debug: cell_id = LEVEL2_感動と称賛の嵐 for tm_slot$name = 感動と称賛の嵐
# Drawing ratio label for: 感動と称賛の嵐 Value: 1.1% at x: 127.1381 y: 899.4691
# Drawing label for: 簡潔な称賛の言葉 at x: 233.3307 y: 1529.719
# Debug: cell_id = LEVEL2_簡潔な称賛の言葉 for tm_slot$name = 簡潔な称賛の言葉
# Drawing ratio label for: 簡潔な称賛の言葉 Value: 0.7% at x: 233.3307 y: 1485.04
# Drawing label for: 関係性への考察 at x: 1128.349 y: 1265.439
# Debug: cell_id = LEVEL2_関係性への考察 for tm_slot$name = 関係性への考察
# Drawing ratio label for: 関係性への考察 Value: 1.9% at x: 1128.349 y: 1217.955
# Drawing label for: 記録更新への祝福 at x: 1680.036 y: 224.0971
# Debug: cell_id = LEVEL2_記録更新への祝福 for tm_slot$name = 記録更新への祝福
# Drawing ratio label for: 記録更新への祝福 Value: 0.4% at x: 1680.036 y: 180.632
# Drawing label for: 金銭的なやり取り at x: 1142.891 y: 960.8771
# Debug: cell_id = LEVEL2_金銭的なやり取り for tm_slot$name = 金銭的なやり取り
# Drawing ratio label for: 金銭的なやり取り Value: 0.6% at x: 1142.891 y: 916.8121
# Drawing label for: 好意的な反応と称賛 at x: 1172.296 y: 351.6246
# Debug: cell_id = LEVEL2_好意的な反応と称賛 for tm_slot$name = 好意的な反応と称賛
# Drawing ratio label for: 好意的な反応と称賛 Value: 1.1% at x: 1172.296 y: 305.7246
# Drawing label for: 豪華さへの圧倒と考察 at x: 1604.497 y: 590.5369
# Debug: cell_id = LEVEL2_豪華さへの圧倒と考察 for tm_slot$name = 豪華さへの圧倒と考察
# Drawing ratio label for: 豪華さへの圧倒と考察 Value: 1.1% at x: 1604.497 y: 544.5395
# Drawing label for: 再生回数の驚異的な伸び at x: 1451.728 y: 762.2344
# Debug: cell_id = LEVEL2_再生回数の驚異的な伸び for tm_slot$name = 再生回数の驚異的な伸び
# Drawing ratio label for: 再生回数の驚異的な伸び Value: 0.6% at x: 1451.728 y: 717.8179
# Drawing label for: 再生回数の驚異的な伸び at x: 530.817 y: 1260.634
# Debug: cell_id = LEVEL2_再生回数の驚異的な伸び for tm_slot$name = 再生回数の驚異的な伸び
# Drawing ratio label for: 再生回数の驚異的な伸び Value: 0.6% at x: 530.817 y: 1216.819
# Drawing label for: 再生回数の驚異的な伸び at x: 721.1964 y: 828.6221
# Debug: cell_id = LEVEL2_再生回数の驚異的な伸び for tm_slot$name = 再生回数の驚異的な伸び
# Drawing ratio label for: 再生回数の驚異的な伸び Value: 0.6% at x: 721.1964 y: 783.845
# Drawing label for: 再生回数増加への祝福 at x: 1926.285 y: 700.0928
# Debug: cell_id = LEVEL2_再生回数増加への祝福 for tm_slot$name = 再生回数増加への祝福
# Drawing ratio label for: 再生回数増加への祝福 Value: 0.6% at x: 1926.285 y: 655.6946
# Drawing label for: 最高のコラボへの称賛 at x: 742.35 y: 44.12712
# Debug: cell_id = LEVEL2_最高のコラボへの称賛 for tm_slot$name = 最高のコラボへの称賛
# Drawing ratio label for: 最高のコラボへの称賛 Value: 0.2% at x: 742.35 y: 1.5006
# Drawing label for: 作品への期待と興奮 at x: 687.9577 y: 479.7866
# Debug: cell_id = LEVEL2_作品への期待と興奮 for tm_slot$name = 作品への期待と興奮
# Drawing ratio label for: 作品への期待と興奮 Value: 0.5% at x: 687.9577 y: 435.7962
# Drawing label for: 作品への称賛と感動 at x: 1842.542 y: 1197.529
# Debug: cell_id = LEVEL2_作品への称賛と感動 for tm_slot$name = 作品への称賛と感動
# Drawing ratio label for: 作品への称賛と感動 Value: 1.2% at x: 1842.542 y: 1149.036
# Drawing label for: 作品への深い感動 at x: 881.5346 y: 1405.235
# Debug: cell_id = LEVEL2_作品への深い感動 for tm_slot$name = 作品への深い感動
# Drawing ratio label for: 作品への深い感動 Value: 1.1% at x: 881.5346 y: 1359.416
# Drawing label for: 作品への深い考察と評価 at x: 1743.784 y: 79.44387
# Debug: cell_id = LEVEL2_作品への深い考察と評価 for tm_slot$name = 作品への深い考察と評価
# Drawing ratio label for: 作品への深い考察と評価 Value: 0.6% at x: 1743.784 y: 35.07555
# Drawing label for: 作品への熱狂的な愛 at x: 71.27609 y: 1260.753
# Debug: cell_id = LEVEL2_作品への熱狂的な愛 for tm_slot$name = 作品への熱狂的な愛
# Drawing ratio label for: 作品への熱狂的な愛 Value: 0.5% at x: 71.27609 y: 1216.828
# Drawing label for: 作品への様々な反応 at x: 272.1055 y: 99.41967
# Debug: cell_id = LEVEL2_作品への様々な反応 for tm_slot$name = 作品への様々な反応
# Drawing ratio label for: 作品への様々な反応 Value: 2.0% at x: 272.1055 y: 53.40656
# Drawing label for: 作品への様々な反応 at x: 763.8119 y: 1859.451
# Debug: cell_id = LEVEL2_作品への様々な反応 for tm_slot$name = 作品への様々な反応
# Drawing ratio label for: 作品への様々な反応 Value: 2.0% at x: 763.8119 y: 1810.564
# Drawing label for: 心を奪われる作品 at x: 1433.214 y: 1228.462
# Debug: cell_id = LEVEL2_心を奪われる作品 for tm_slot$name = 心を奪われる作品
# Drawing ratio label for: 心を奪われる作品 Value: 0.8% at x: 1433.214 y: 1183.57
# Drawing label for: 神レベルのコラボ at x: 823.5066 y: 569.3006
# Debug: cell_id = LEVEL2_神レベルのコラボ for tm_slot$name = 神レベルのコラボ
# Drawing ratio label for: 神レベルのコラボ Value: 0.7% at x: 823.5066 y: 524.4516
# Drawing label for: 推しコラボへの興奮 at x: 648.3369 y: 661.7681
# Debug: cell_id = LEVEL2_推しコラボへの興奮 for tm_slot$name = 推しコラボへの興奮
# Drawing ratio label for: 推しコラボへの興奮 Value: 1.2% at x: 648.3369 y: 615.6367
# Drawing label for: 推しへの感謝と祝福 at x: 132.9871 y: 729.9288
# Debug: cell_id = LEVEL2_推しへの感謝と祝福 for tm_slot$name = 推しへの感謝と祝福
# Drawing ratio label for: 推しへの感謝と祝福 Value: 1.5% at x: 132.9871 y: 682.9228
# Drawing label for: 推し活の喜びと誇り at x: 1205.13 y: 1731.594
# Debug: cell_id = LEVEL2_推し活の喜びと誇り for tm_slot$name = 推し活の喜びと誇り
# Drawing ratio label for: 推し活の喜びと誇り Value: 1.0% at x: 1205.13 y: 1685.685
# Drawing label for: 世界からの称賛 at x: 1557.143 y: 1058.084
# Debug: cell_id = LEVEL2_世界からの称賛 for tm_slot$name = 世界からの称賛
# Drawing ratio label for: 世界からの称賛 Value: 0.7% at x: 1557.143 y: 1011.737
# Drawing label for: 世界を魅了するコラボ at x: 536.8759 y: 892.6254
# Debug: cell_id = LEVEL2_世界を魅了するコラボ for tm_slot$name = 世界を魅了するコラボ
# Drawing ratio label for: 世界を魅了するコラボ Value: 1.0% at x: 536.8759 y: 846.5762
# Drawing label for: 世界的な反響と感動 at x: 1662.807 y: 904.069
# Debug: cell_id = LEVEL2_世界的な反響と感動 for tm_slot$name = 世界的な反響と感動
# Drawing ratio label for: 世界的な反響と感動 Value: 1.0% at x: 1662.807 y: 858.5496
# Drawing label for: 誕生日祝いと祝福 at x: 1674.588 y: 375.8113
# Debug: cell_id = LEVEL2_誕生日祝いと祝福 for tm_slot$name = 誕生日祝いと祝福
# Drawing ratio label for: 誕生日祝いと祝福 Value: 0.7% at x: 1674.588 y: 330.9698
# Drawing label for: 誕生日祝いと熱狂的な称賛 at x: 712.4436 y: 323.4503
# Debug: cell_id = LEVEL2_誕生日祝いと熱狂的な称賛 for tm_slot$name = 誕生日祝いと熱狂的な称賛
# Drawing ratio label for: 誕生日祝いと熱狂的な称賛 Value: 1.0% at x: 712.4436 y: 277.8162
# Drawing label for: 天才たちの芸術 at x: 91.28076 y: 1584.199
# Debug: cell_id = LEVEL2_天才たちの芸術 for tm_slot$name = 天才たちの芸術
# Drawing ratio label for: 天才たちの芸術 Value: 0.7% at x: 91.28076 y: 1539.387
# Drawing label for: 天才への称賛と感動 at x: 1138.551 y: 508.3267
# Debug: cell_id = LEVEL2_天才への称賛と感動 for tm_slot$name = 天才への称賛と感動
# Drawing ratio label for: 天才への称賛と感動 Value: 0.8% at x: 1138.551 y: 463.3026
# Drawing label for: 日本の誇りへの賛辞 at x: 1010.81 y: 613.8657
# Debug: cell_id = LEVEL2_日本の誇りへの賛辞 for tm_slot$name = 日本の誇りへの賛辞
# Drawing ratio label for: 日本の誇りへの賛辞 Value: 0.7% at x: 1010.81 y: 569.3489
# Drawing label for: 美しさと楽曲への共感 at x: 560.8584 y: 148.2944
# Debug: cell_id = LEVEL2_美しさと楽曲への共感 for tm_slot$name = 美しさと楽曲への共感
# Drawing ratio label for: 美しさと楽曲への共感 Value: 2.2% at x: 560.8584 y: 99.88008
# Drawing label for: 美しさへの感動 at x: 1301.427 y: 1093.585
# Debug: cell_id = LEVEL2_美しさへの感動 for tm_slot$name = 美しさへの感動
# Drawing ratio label for: 美しさへの感動 Value: 1.2% at x: 1301.427 y: 1047.348
# Drawing label for: 美しさへの称賛 at x: 1938.492 y: 1659.072
# Debug: cell_id = LEVEL2_美しさへの称賛 for tm_slot$name = 美しさへの称賛
# Drawing ratio label for: 美しさへの称賛 Value: 0.6% at x: 1938.492 y: 1614.721
# Drawing label for: 米津と羽生の輝きに魅了 at x: 1398.028 y: 1522.673
# Debug: cell_id = LEVEL2_米津と羽生の輝きに魅了 for tm_slot$name = 米津と羽生の輝きに魅了
# Drawing ratio label for: 米津と羽生の輝きに魅了 Value: 1.7% at x: 1398.028 y: 1475.139
# Drawing label for: 米津玄師への称賛 at x: 1350.991 y: 584.4186
# Debug: cell_id = LEVEL2_米津玄師への称賛 for tm_slot$name = 米津玄師への称賛
# Drawing ratio label for: 米津玄師への称賛 Value: 1.9% at x: 1350.991 y: 536.5639
# Drawing label for: 米津玄師への誕生日祝い at x: 443.5605 y: 1746.18
# Debug: cell_id = LEVEL2_米津玄師への誕生日祝い for tm_slot$name = 米津玄師への誕生日祝い
# Drawing ratio label for: 米津玄師への誕生日祝い Value: 0.2% at x: 443.5605 y: 1703.798
# Drawing label for: 魅了されるコラボ at x: 601.2989 y: 1652.131
# Debug: cell_id = LEVEL2_魅了されるコラボ for tm_slot$name = 魅了されるコラボ
# Drawing ratio label for: 魅了されるコラボ Value: 1.4% at x: 601.2989 y: 1605.264
# Drawing label for: 無料視聴への驚き at x: 1571.007 y: 788.5167
# Debug: cell_id = LEVEL2_無料視聴への驚き for tm_slot$name = 無料視聴への驚き
# Drawing ratio label for: 無料視聴への驚き Value: 0.5% at x: 1571.007 y: 744.5508
# Drawing label for: 踊ってみたへの期待 at x: 783.31 y: 920.2465
# Debug: cell_id = LEVEL2_踊ってみたへの期待 for tm_slot$name = 踊ってみたへの期待
# Drawing ratio label for: 踊ってみたへの期待 Value: 0.4% at x: 783.31 y: 876.7569
# Drawing label for: 涙を誘う美しさ at x: 819.8375 y: 1580.973
# Debug: cell_id = LEVEL2_涙を誘う美しさ for tm_slot$name = 涙を誘う美しさ
# Drawing ratio label for: 涙を誘う美しさ Value: 0.3% at x: 819.8375 y: 1537.096
# ### 処理が正常に終了しました ###
# plot without title
